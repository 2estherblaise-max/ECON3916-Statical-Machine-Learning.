# %% [markdown]
# <a href="https://colab.research.google.com/github/2estherblaise-max/ECON3916-Statical-Machine-Learning./blob/main/Lab12/Lab12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import statsmodels.formula.api as smf
from statsmodels.tools.eval_measures import rmse
import matplotlib.pyplot as plt

# %%
import pandas as pd
import numpy as np
import statsmodels.formula.api as smf
from statsmodels.tools.eval_measures import rmse
import matplotlib.pyplot as plt

# Step 1: Ingestion from external source
url = 'https://raw.githubusercontent.com/2estherblaise-max/ECON3916-Statical-Machine-Learning./refs/heads/main/Data/Zillow_ZHVI_2026_Micro.csv'
df = pd.read_csv(url)

#Display the first few rows to verify ingestion
df.head()
# Out:
#    Home_Value  Square_Footage  Property_Age  Distance_to_Transit  \
# 0   329705.74          1941.0           5.5                 6.45
# 1   183343.63          1364.3          35.2                 2.15
# 2   354551.73          2386.9          52.4                 0.75
# 3   325773.17          2192.1          50.2                 5.25
# 4   359743.12          3069.8          66.5                12.69
#
#   School_District_Rating
# 0              Excellent
# 1                Average
# 2                   Good
# 3              Excellent
# 4              Excellent

# %%
# Step 2: Defining the formula
# Utilizing the R-style patsy formula interface allows for elegant, readable model specification
formula_0='Home_Value ~ Square_Footage + Property_Age + Distance_to_Transit + School_District_Rating'

# %%
# Step 3: Fitting the model and printing the summary
model_0 = smf.ols(formula=formula_0,data=df)
results = model_0.fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:             Home_Value   R-squared:                       0.766
# Model:                            OLS   Adj. R-squared:                  0.765
# Method:                 Least Squares   F-statistic:                     542.5
# Date:                Mon, 16 Mar 2026   Prob (F-statistic):          2.81e-309
# Time:                        20:02:22   Log-Likelihood:                -12072.
# No. Observations:                1000   AIC:                         2.416e+04
# Df Residuals:                     993   BIC:                         2.419e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                                           coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# ...

# %%
y_pred = results.predict(df)

# %%
# Step 5: Calculate RMSE between the actuals and the predictions
model_rmse =  rmse(df["Home_Value"],y_pred)
print(f"\nThe Predictive RMSE is: ${model_rmse:,.2f}")
# Out:
# The Predictive RMSE is: $42,316.69
